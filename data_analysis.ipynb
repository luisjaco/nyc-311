# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./data/nyc311.csv')
# Out:
# /var/folders/x4/j70qy1ns0gdg8282hfmvlbm80000gn/T/ipykernel_70786/2713477687.py:1: DtypeWarning: Columns (0: Incident Zip) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/nyc311.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9386300 entries, 0 to 9386299
# Data columns (total 24 columns):
#  #   Column                                Dtype
# ---  ------                                -----
#  0   Unique Key                            int64
#  1   Created Date                          str
#  2   Closed Date                           str
#  3   Agency                                str
#  4   Agency Name                           str
#  5   Problem (formerly Complaint Type)     str
#  6   Problem Detail (formerly Descriptor)  str
#  7   Additional Details                    str
#  8   Location Type                         str
#  9   Incident Zip                          object
#  10  Incident Address                      str
#  11  Street Name                           str
#  12  Address Type                          str
#  13  City                                  str
#  14  Landmark                              str
#  15  Status                                str
# ...
